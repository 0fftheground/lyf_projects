# %%
import pandas as pd

# %%
df= pd.read_excel('E:\Population\湖南行政区编码.xlsx')

# %%
df.head()
# Out:
#    Unnamed: 0  village_code province_name city_name district_name town_name  \
# 0           0  430203004009           湖南省       株洲市           芦淞区     董家段街道
# 1           1  430203004014           湖南省       株洲市           芦淞区     董家段街道
# 2           2  430203004201           湖南省       株洲市           芦淞区     董家段街道
# 3           3  430203004204           湖南省       株洲市           芦淞区     董家段街道
# 4           4  430203004207           湖南省       株洲市           芦淞区     董家段街道
#
#   village_name
# 0      劳动社区居委会
# 1      新泉社区居委会
# 2       五里墩村委会
# 3        百井村委会
# 4       朱田铺村委会

# %%
dt_jsq=df[df.district_name=='君山区']
dt_jsq
# Out:
#        Unnamed: 0  village_code province_name city_name district_name  \
# 28660       28660  430611001202           湖南省       岳阳市           君山区
# 28661       28661  430611001200           湖南省       岳阳市           君山区
# 28662       28662  430611001008           湖南省       岳阳市           君山区
# 28663       28663  430611001203           湖南省       岳阳市           君山区
# 28664       28664  430611001001           湖南省       岳阳市           君山区
# 28665       28665  430611001007           湖南省       岳阳市           君山区
# 28666       28666  430611001003           湖南省       岳阳市           君山区
# 28667       28667  430611001205           湖南省       岳阳市           君山区
# 28668       28668  430611001206           湖南省       岳阳市           君山区
# 28669       28669  430611001216           湖南省       岳阳市           君山区
# 28670       28670  430611001214           湖南省       岳阳市           君山区
# 28671       28671  430611001204           湖南省       岳阳市           君山区
# ...

# %%
dt_jsq.drop_duplicates(subset = 'town_name', keep = 'first')
# Out:
#        Unnamed: 0  village_code province_name city_name district_name  \
# 28660       28660  430611001202           湖南省       岳阳市           君山区
# 28685       28685  430611103005           湖南省       岳阳市           君山区
# 28708       28708  430611102002           湖南省       岳阳市           君山区
# 28721       28721  430611101205           湖南省       岳阳市           君山区
#
#       town_name village_name
# 28660     柳林洲街道          挂口村
# 28685      钱粮湖镇        托龙山社区
# 28708       许市镇        洪水港社区
# 28721      广兴洲镇         六支渠村

# %%
dt_jsq.drop_duplicates(subset = 'town_name', keep = 'first').shape[0]
# Out:
# 4

# %%
dt_jsq.to_excel('E:\Population\湖南\君山区\君山区行政编码.xlsx')
